# %% [markdown]
# <a href="https://colab.research.google.com/github/Varshini0051/Rag_chatbot/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RAG Chatbot – Hands-on Lab
#
# In this notebook you will learn:
#
# 1. What is RAG (Retrieval Augmented Generation)
# 2. How to create embeddings
# 3. How to store them in a vector database (FAISS)
# 4. How to retrieve relevant context
# 5. How to generate answers using:
#    - Local LLM (Free)
#    - Cloud LLM (Optional)
#
# Goal: Build your own chatbot over custom documents.

# %%
# !pip install -q sentence-transformers faiss-cpu transformers accelerate groq

# %% [markdown]
# LLMs do not know your private data.
#
# RAG Flow:
# User Question → Convert to embedding
# → Search similar documents
# → Add context to prompt
# → LLM generates answer

# %%
documents = [
    "RAG stands for Retrieval Augmented Generation.",
    "LLMs generate text based on patterns learned during training.",
    "Embeddings convert text into numerical vectors.",
    "FAISS is a library for fast similarity search.",
    "Vector databases help retrieve relevant information."
]

print("Loaded", len(documents), "documents")
# Out:
# Loaded 5 documents

# %% [markdown]
# 4️⃣ Create Embeddings (Local)

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

embed_model = SentenceTransformer("all-MiniLM-L6-v2")

doc_embeddings = embed_model.encode(documents)
doc_embeddings.shape
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# (5, 384)

# %% [markdown]
# Store in FAISS (Vector DB)

# %%
import faiss

dimension = doc_embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(np.array(doc_embeddings))

print("FAISS index created with", index.ntotal, "vectors")
# Out:
# FAISS index created with 5 vectors

# %%
def retrieve(query, k=2):
    query_embedding = embed_model.encode([query])
    distances, indices = index.search(np.array(query_embedding), k)
    results = [documents[i] for i in indices[0]]
    return results

# %%
retrieve("What is RAG?")
# Out:
# ['RAG stands for Retrieval Augmented Generation.',
#  'Embeddings convert text into numerical vectors.']

# %%
from transformers import pipeline

local_llm = pipeline(
    task="text-generation",   # Updated task name
    model="google/flan-t5-base",
    max_new_tokens=128
)
# Out:
# Loading weights:   0%|          | 0/282 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# ...

# %% [markdown]
# Local LLM (No API Required)

# %%
def rag_local(query):
    context = retrieve(query)
    context_text = " ".join(context)

    prompt = f"""
    Answer the question using the context.

    Context: {context_text}
    Question: {query}
    Answer:
    """

    response = local_llm(prompt)
    return response[0]["generated_text"]

# %%
rag_local("Explain RAG")
# Out:
# Both `max_new_tokens` (=128) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# '\n    Answer the question using the context.\n\n    Context: RAG stands for Retrieval Augmented Generation. Embeddings convert text into numerical vectors.\n    Question: Explain RAG\n    Answer:\n    U, V_1, HloV1, DshWi = 3B4, HD_I, O:m_1, R.e9 x=v[h[M ei+1/9016'

# %%
# !pip install -q pypdf

# %%
from google.colab import files
uploaded = files.upload()

filename = list(uploaded.keys())[0]
print("Uploaded:", filename)
# Out:
#      <input type="file" id="files-3f671926-6dd0-416c-8ca2-91f6d5af33d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3f671926-6dd0-416c-8ca2-91f6d5af33d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from pypdf import PdfReader

def extract_text_from_pdf(file_path):
    reader = PdfReader(file_path)
    text = ""
    for page in reader.pages:
        text += page.extract_text() + "\n"
    return text

text = extract_text_from_pdf(filename)

print("Extracted text length:", len(text))
print(text[:500])  # preview
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2414783357.py in <cell line: 0>()
# ----> 1 from pypdf import PdfReader
#       2
#       3 def extract_text_from_pdf(file_path):
#       4     reader = PdfReader(file_path)
#       5     text = ""
#
# ModuleNotFoundError: No module named 'pypdf'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
def chunk_text(text, chunk_size=500):
    chunks = []
    for i in range(0, len(text), chunk_size):
        chunks.append(text[i:i+chunk_size])
    return chunks

documents = chunk_text(text)

print("Total chunks:", len(documents))

# %%
doc_embeddings = embed_model.encode(documents)

import faiss
import numpy as np

index = faiss.IndexFlatL2(doc_embeddings.shape[1])
index.add(np.array(doc_embeddings))

print("PDF indexed successfully!")

# %%
def rag_local(query):
    context = retrieve(query)
    context_text = " ".join(context)

    prompt = f"""
You are an assistant. Answer based only on the context.

Context:
{context_text}

Question:
{query}

Answer:
"""

    response = local_llm(prompt)
    return response[0]["generated_text"]

# %%
rag_local("What is the role of this candidate is he a doctor")

# %% [markdown]
# You built:
#
# - Embeddings
# - Vector database
# - Retrieval system
# - Prompt engineering
# - Local LLM
# - Cloud LLM
# - End-to-end RAG pipeline
